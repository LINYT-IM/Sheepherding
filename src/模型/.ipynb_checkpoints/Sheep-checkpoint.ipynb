# %%
from gurobipy import*
import math

# %%
p = {
0:[11,1],
1: [15,4],
2: [20,10]}
x = [1,5]
dist = {}
for key in p:
    dist["x",key] = math.floor(math.sqrt(pow(x[0] - p[key][0],2) + pow(x[1] - p[key][1],2))*100)/100

# 最大初速
V = 3
dist
# Out:
# {('x', 0): 10.77, ('x', 1): 14.03, ('x', 2): 19.64}

# %%
model = Model("Sheep")
x = {}
# cost variable
c = {}
t = 40
M = 99999
for i in p:
    for j in range(t):
        x[i, j] = model.addVar(vtype = GRB.BINARY, name = "x{},{}".format(i,j))
        c[i,j] = model.addVar(vtype = GRB.INTEGER, name = "c{},{}".format(i,j))
# cost constraints
for i in p:
    for j in range(t):
        model.addConstr(V*x[i,j]*quicksum(x[k,j] for k in p) <= c[i,j], name =  "(1)")
        model.addConstr(M*(1-x[i,j]) + V*x[i,j] >= c[i,j], name = "(2)")
        for k in range(max(0, j-V+1), j):  
            model.addConstr((V-(j-k))*x[i,k]*quicksum(x[k,j] for k in p) <= c[i,j], name = "(1)")
            model.addConstr(quicksum(x[i,n] for n in range(k+1, j+1))*M + M*(1-x[i,k]) +  (V-(j-k)) *x[i,k] >= c[i,j], name = "(2)")
        model.addConstr(0 <= c[i,j], name = "(3)")
        model.addConstr(quicksum(x[i,k] for k in range(max(0, j-V+1), j+1))*M >= c[i,j], name = "(3)" )
#         model.addConstr(M*quicksum(x[k,j] for k in p) >= c[i,j], name = "(test)" )
        

# distance constraints
for i in p:
#     lhs = LinExpr(0)
#     for j in range(t):
#         lhs += x[i,j]*c[i,j]
#         if(j >= 1):
#             lhs += x[i,j-1]*c[i,j]
#         if(j >= 2):
#             lhs += x[i,j-2]*c[i,j]
#     model.addConstr(lhs >= dist['x', i], name = "(3)")
    model.addConstr(quicksum(c[i,j] for j in range(t)) >= dist['x', i], name = "(4)")
    
# 無人機至少停留在　a , b, c　其中一點（或沒有）
for j in range(t):
    model.addConstr(quicksum(x[i,j] for i in p) <= 1, name = "(5)")
# t-1 沒有停留時，ｔ也會＝０
for j in range(1,t):
    model.addConstr(quicksum(x[i,j] for i in p) <= quicksum(x[i,j-1] for i in p), name= "(6)")

# non-negative
for i in p:
    for j in range(t):
        model.addConstr(x[i,j] >= 0, name="(7)")

# %%
# objective
lhs = LinExpr(0)
for i in p:
#     for j in range(t):
#         lhs += x[i,j]*c[i,j]
#         if(j >= 1):
#             lhs+= x[i,j-1]*c[i,j]
#         if(j >= 2):
#             lhs += x[i,j-2]*c[i,j]
    lhs += quicksum(c[i,j] for j in range(t))
# minimize time spend
lhs_t = LinExpr(quicksum(x[i,j] for i in p for j in range(t)))
model.setObjective(lhs,GRB.MINIMIZE)
model.update()
# model.display()
model.optimize()
print("Optimize value = ", model.ObjVal)
# Out:
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 793 rows, 240 columns and 2232 nonzeros
# Model fingerprint: 0x6fcf57e7
# Model has 351 quadratic constraints
# Variable types: 0 continuous, 240 integer (120 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+05]
#   QMatrix range    [1e+00, 3e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+05]
# Presolve added 95 rows and 0 columns
# Presolve removed 0 rows and 3 columns
# Presolve time: 0.02s
# Presolved: 888 rows, 237 columns, 3309 nonzeros
# Variable types: 0 continuous, 237 integer (120 binary)
# Found heuristic solution: objective 50.0000000
#
# Root relaxation: objective 4.600000e+01, 178 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   46.00000    0   22   50.00000   46.00000  8.00%     -    0s
#      0     0   46.00000    0   66   50.00000   46.00000  8.00%     -    0s
# H    0     0                      46.0000000   46.00000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 1
#   Implied bound: 8
#   MIR: 16
#   StrongCG: 2
#
# Explored 1 nodes (531 simplex iterations) in 0.09 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 46 50
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.600000000000e+01, best bound 4.600000000000e+01, gap 0.0000%
# Optimize value =  46.0

# %%
model.display()
# Out:
# Minimize
#    <gurobi.LinExpr: c0,0 + c0,1 + c0,2 + c0,3 + c0,4 + c0,5 + c0,6 + c0,7 + c0,8 + c0,9 + c0,10 + c0,11 + c0,12 + c0,13 + c0,14 + c0,15 + c0,16 + c0,17 + c0,18 + c0,19 + c0,20 + c0,21 + c0,22 + c0,23 + c0,24 + c0,25 + c0,26 + c0,27 + c0,28 + c0,29 + c0,30 + c0,31 + c0,32 + c0,33 + c0,34 + c0,35 + c0,36 + c0,37 + c0,38 + c0,39 + c1,0 + c1,1 + c1,2 + c1,3 + c1,4 + c1,5 + c1,6 + c1,7 + c1,8 + c1,9 + c1,10 + c1,11 + c1,12 + c1,13 + c1,14 + c1,15 + c1,16 + c1,17 + c1,18 + c1,19 + c1,20 + c1,21 + c1,22 + c1,23 + c1,24 + c1,25 + c1,26 + c1,27 + c1,28 + c1,29 + c1,30 + c1,31 + c1,32 + c1,33 + c1,34 + c1,35 + c1,36 + c1,37 + c1,38 + c1,39 + c2,0 + c2,1 + c2,2 + c2,3 + c2,4 + c2,5 + c2,6 + c2,7 + c2,8 + c2,9 + c2,10 + c2,11 + c2,12 + c2,13 + c2,14 + c2,15 + c2,16 + c2,17 + c2,18 + c2,19 + c2,20 + c2,21 + c2,22 + c2,23 + c2,24 + c2,25 + c2,26 + c2,27 + c2,28 + c2,29 + c2,30 + c2,31 + c2,32 + c2,33 + c2,34 + c2,35 + c2,36 + c2,37 + c2,38 + c2,39>
# Subject To
#    (1) : <gurobi.LinExpr: 3.0 x0,0 + -1.0 c0,0> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x0,0 + -1.0 c0,0> >= -99999.0
#    (3) : <gurobi.LinExpr: c0,0> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x0,0 + -1.0 c0,0> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,0 + -1.0 c0,0 + 99999.0 x1,0 + 99999.0 x2,0> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x0,1 + -1.0 c0,1> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x0,1 + -1.0 c0,1> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x0,0 + -1.0 c0,1> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x0,0 + 99999.0 x0,1 + -1.0 c0,1> >= -99999.0
#    (3) : <gurobi.LinExpr: c0,1> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x0,0 + 99999.0 x0,1 + -1.0 c0,1> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,1 + -1.0 c0,1 + 99999.0 x1,1 + 99999.0 x2,1> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x0,2 + -1.0 c0,2> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x0,2 + -1.0 c0,2> >= -99999.0
#    (1) : <gurobi.LinExpr: x0,0 + -1.0 c0,2> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x0,0 + 99999.0 x0,1 + 99999.0 x0,2 + -1.0 c0,2> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x0,1 + -1.0 c0,2> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x0,1 + 99999.0 x0,2 + -1.0 c0,2> >= -99999.0
#    (3) : <gurobi.LinExpr: c0,2> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x0,0 + 99999.0 x0,1 + 99999.0 x0,2 + -1.0 c0,2> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,2 + -1.0 c0,2 + 99999.0 x1,2 + 99999.0 x2,2> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x0,3 + -1.0 c0,3> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x0,3 + -1.0 c0,3> >= -99999.0
#    (1) : <gurobi.LinExpr: x0,1 + -1.0 c0,3> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x0,1 + 99999.0 x0,2 + 99999.0 x0,3 + -1.0 c0,3> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x0,2 + -1.0 c0,3> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x0,2 + 99999.0 x0,3 + -1.0 c0,3> >= -99999.0
#    (3) : <gurobi.LinExpr: c0,3> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x0,1 + 99999.0 x0,2 + 99999.0 x0,3 + -1.0 c0,3> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,3 + -1.0 c0,3 + 99999.0 x1,3 + 99999.0 x2,3> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x0,4 + -1.0 c0,4> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x0,4 + -1.0 c0,4> >= -99999.0
#    (1) : <gurobi.LinExpr: x0,2 + -1.0 c0,4> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x0,2 + 99999.0 x0,3 + 99999.0 x0,4 + -1.0 c0,4> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x0,3 + -1.0 c0,4> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x0,3 + 99999.0 x0,4 + -1.0 c0,4> >= -99999.0
#    (3) : <gurobi.LinExpr: c0,4> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x0,2 + 99999.0 x0,3 + 99999.0 x0,4 + -1.0 c0,4> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,4 + -1.0 c0,4 + 99999.0 x1,4 + 99999.0 x2,4> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x0,5 + -1.0 c0,5> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x0,5 + -1.0 c0,5> >= -99999.0
#    (1) : <gurobi.LinExpr: x0,3 + -1.0 c0,5> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x0,3 + 99999.0 x0,4 + 99999.0 x0,5 + -1.0 c0,5> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x0,4 + -1.0 c0,5> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x0,4 + 99999.0 x0,5 + -1.0 c0,5> >= -99999.0
#    (3) : <gurobi.LinExpr: c0,5> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x0,3 + 99999.0 x0,4 + 99999.0 x0,5 + -1.0 c0,5> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,5 + -1.0 c0,5 + 99999.0 x1,5 + 99999.0 x2,5> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x0,6 + -1.0 c0,6> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x0,6 + -1.0 c0,6> >= -99999.0
#    (1) : <gurobi.LinExpr: x0,4 + -1.0 c0,6> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x0,4 + 99999.0 x0,5 + 99999.0 x0,6 + -1.0 c0,6> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x0,5 + -1.0 c0,6> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x0,5 + 99999.0 x0,6 + -1.0 c0,6> >= -99999.0
#    (3) : <gurobi.LinExpr: c0,6> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x0,4 + 99999.0 x0,5 + 99999.0 x0,6 + -1.0 c0,6> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,6 + -1.0 c0,6 + 99999.0 x1,6 + 99999.0 x2,6> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x0,7 + -1.0 c0,7> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x0,7 + -1.0 c0,7> >= -99999.0
#    (1) : <gurobi.LinExpr: x0,5 + -1.0 c0,7> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x0,5 + 99999.0 x0,6 + 99999.0 x0,7 + -1.0 c0,7> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x0,6 + -1.0 c0,7> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x0,6 + 99999.0 x0,7 + -1.0 c0,7> >= -99999.0
#    (3) : <gurobi.LinExpr: c0,7> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x0,5 + 99999.0 x0,6 + 99999.0 x0,7 + -1.0 c0,7> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,7 + -1.0 c0,7 + 99999.0 x1,7 + 99999.0 x2,7> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x0,8 + -1.0 c0,8> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x0,8 + -1.0 c0,8> >= -99999.0
#    (1) : <gurobi.LinExpr: x0,6 + -1.0 c0,8> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x0,6 + 99999.0 x0,7 + 99999.0 x0,8 + -1.0 c0,8> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x0,7 + -1.0 c0,8> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x0,7 + 99999.0 x0,8 + -1.0 c0,8> >= -99999.0
#    (3) : <gurobi.LinExpr: c0,8> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x0,6 + 99999.0 x0,7 + 99999.0 x0,8 + -1.0 c0,8> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,8 + -1.0 c0,8 + 99999.0 x1,8 + 99999.0 x2,8> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x0,9 + -1.0 c0,9> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x0,9 + -1.0 c0,9> >= -99999.0
#    (1) : <gurobi.LinExpr: x0,7 + -1.0 c0,9> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x0,7 + 99999.0 x0,8 + 99999.0 x0,9 + -1.0 c0,9> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x0,8 + -1.0 c0,9> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x0,8 + 99999.0 x0,9 + -1.0 c0,9> >= -99999.0
#    (3) : <gurobi.LinExpr: c0,9> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x0,7 + 99999.0 x0,8 + 99999.0 x0,9 + -1.0 c0,9> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,9 + -1.0 c0,9 + 99999.0 x1,9 + 99999.0 x2,9> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x0,10 + -1.0 c0,10> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x0,10 + -1.0 c0,10> >= -99999.0
#    (1) : <gurobi.LinExpr: x0,8 + -1.0 c0,10> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x0,8 + 99999.0 x0,9 + 99999.0 x0,10 + -1.0 c0,10> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x0,9 + -1.0 c0,10> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x0,9 + 99999.0 x0,10 + -1.0 c0,10> >= -99999.0
#    (3) : <gurobi.LinExpr: c0,10> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x0,8 + 99999.0 x0,9 + 99999.0 x0,10 + -1.0 c0,10> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,10 + -1.0 c0,10 + 99999.0 x1,10 + 99999.0 x2,10> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x0,11 + -1.0 c0,11> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x0,11 + -1.0 c0,11> >= -99999.0
#    (1) : <gurobi.LinExpr: x0,9 + -1.0 c0,11> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x0,9 + 99999.0 x0,10 + 99999.0 x0,11 + -1.0 c0,11> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x0,10 + -1.0 c0,11> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x0,10 + 99999.0 x0,11 + -1.0 c0,11> >= -99999.0
#    (3) : <gurobi.LinExpr: c0,11> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x0,9 + 99999.0 x0,10 + 99999.0 x0,11 + -1.0 c0,11> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,11 + -1.0 c0,11 + 99999.0 x1,11 + 99999.0 x2,11> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x0,12 + -1.0 c0,12> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x0,12 + -1.0 c0,12> >= -99999.0
#    (1) : <gurobi.LinExpr: x0,10 + -1.0 c0,12> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x0,10 + 99999.0 x0,11 + 99999.0 x0,12 + -1.0 c0,12> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x0,11 + -1.0 c0,12> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x0,11 + 99999.0 x0,12 + -1.0 c0,12> >= -99999.0
#    (3) : <gurobi.LinExpr: c0,12> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x0,10 + 99999.0 x0,11 + 99999.0 x0,12 + -1.0 c0,12> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,12 + -1.0 c0,12 + 99999.0 x1,12 + 99999.0 x2,12> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x0,13 + -1.0 c0,13> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x0,13 + -1.0 c0,13> >= -99999.0
#    (1) : <gurobi.LinExpr: x0,11 + -1.0 c0,13> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x0,11 + 99999.0 x0,12 + 99999.0 x0,13 + -1.0 c0,13> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x0,12 + -1.0 c0,13> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x0,12 + 99999.0 x0,13 + -1.0 c0,13> >= -99999.0
#    (3) : <gurobi.LinExpr: c0,13> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x0,11 + 99999.0 x0,12 + 99999.0 x0,13 + -1.0 c0,13> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,13 + -1.0 c0,13 + 99999.0 x1,13 + 99999.0 x2,13> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x0,14 + -1.0 c0,14> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x0,14 + -1.0 c0,14> >= -99999.0
#    (1) : <gurobi.LinExpr: x0,12 + -1.0 c0,14> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x0,12 + 99999.0 x0,13 + 99999.0 x0,14 + -1.0 c0,14> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x0,13 + -1.0 c0,14> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x0,13 + 99999.0 x0,14 + -1.0 c0,14> >= -99999.0
#    (3) : <gurobi.LinExpr: c0,14> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x0,12 + 99999.0 x0,13 + 99999.0 x0,14 + -1.0 c0,14> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,14 + -1.0 c0,14 + 99999.0 x1,14 + 99999.0 x2,14> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x0,15 + -1.0 c0,15> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x0,15 + -1.0 c0,15> >= -99999.0
#    (1) : <gurobi.LinExpr: x0,13 + -1.0 c0,15> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x0,13 + 99999.0 x0,14 + 99999.0 x0,15 + -1.0 c0,15> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x0,14 + -1.0 c0,15> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x0,14 + 99999.0 x0,15 + -1.0 c0,15> >= -99999.0
#    (3) : <gurobi.LinExpr: c0,15> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x0,13 + 99999.0 x0,14 + 99999.0 x0,15 + -1.0 c0,15> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,15 + -1.0 c0,15 + 99999.0 x1,15 + 99999.0 x2,15> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x0,16 + -1.0 c0,16> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x0,16 + -1.0 c0,16> >= -99999.0
#    (1) : <gurobi.LinExpr: x0,14 + -1.0 c0,16> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x0,14 + 99999.0 x0,15 + 99999.0 x0,16 + -1.0 c0,16> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x0,15 + -1.0 c0,16> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x0,15 + 99999.0 x0,16 + -1.0 c0,16> >= -99999.0
#    (3) : <gurobi.LinExpr: c0,16> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x0,14 + 99999.0 x0,15 + 99999.0 x0,16 + -1.0 c0,16> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,16 + -1.0 c0,16 + 99999.0 x1,16 + 99999.0 x2,16> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x0,17 + -1.0 c0,17> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x0,17 + -1.0 c0,17> >= -99999.0
#    (1) : <gurobi.LinExpr: x0,15 + -1.0 c0,17> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x0,15 + 99999.0 x0,16 + 99999.0 x0,17 + -1.0 c0,17> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x0,16 + -1.0 c0,17> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x0,16 + 99999.0 x0,17 + -1.0 c0,17> >= -99999.0
#    (3) : <gurobi.LinExpr: c0,17> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x0,15 + 99999.0 x0,16 + 99999.0 x0,17 + -1.0 c0,17> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,17 + -1.0 c0,17 + 99999.0 x1,17 + 99999.0 x2,17> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x0,18 + -1.0 c0,18> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x0,18 + -1.0 c0,18> >= -99999.0
#    (1) : <gurobi.LinExpr: x0,16 + -1.0 c0,18> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x0,16 + 99999.0 x0,17 + 99999.0 x0,18 + -1.0 c0,18> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x0,17 + -1.0 c0,18> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x0,17 + 99999.0 x0,18 + -1.0 c0,18> >= -99999.0
#    (3) : <gurobi.LinExpr: c0,18> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x0,16 + 99999.0 x0,17 + 99999.0 x0,18 + -1.0 c0,18> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,18 + -1.0 c0,18 + 99999.0 x1,18 + 99999.0 x2,18> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x0,19 + -1.0 c0,19> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x0,19 + -1.0 c0,19> >= -99999.0
#    (1) : <gurobi.LinExpr: x0,17 + -1.0 c0,19> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x0,17 + 99999.0 x0,18 + 99999.0 x0,19 + -1.0 c0,19> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x0,18 + -1.0 c0,19> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x0,18 + 99999.0 x0,19 + -1.0 c0,19> >= -99999.0
#    (3) : <gurobi.LinExpr: c0,19> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x0,17 + 99999.0 x0,18 + 99999.0 x0,19 + -1.0 c0,19> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,19 + -1.0 c0,19 + 99999.0 x1,19 + 99999.0 x2,19> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x0,20 + -1.0 c0,20> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x0,20 + -1.0 c0,20> >= -99999.0
#    (1) : <gurobi.LinExpr: x0,18 + -1.0 c0,20> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x0,18 + 99999.0 x0,19 + 99999.0 x0,20 + -1.0 c0,20> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x0,19 + -1.0 c0,20> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x0,19 + 99999.0 x0,20 + -1.0 c0,20> >= -99999.0
#    (3) : <gurobi.LinExpr: c0,20> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x0,18 + 99999.0 x0,19 + 99999.0 x0,20 + -1.0 c0,20> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,20 + -1.0 c0,20 + 99999.0 x1,20 + 99999.0 x2,20> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x0,21 + -1.0 c0,21> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x0,21 + -1.0 c0,21> >= -99999.0
#    (1) : <gurobi.LinExpr: x0,19 + -1.0 c0,21> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x0,19 + 99999.0 x0,20 + 99999.0 x0,21 + -1.0 c0,21> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x0,20 + -1.0 c0,21> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x0,20 + 99999.0 x0,21 + -1.0 c0,21> >= -99999.0
#    (3) : <gurobi.LinExpr: c0,21> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x0,19 + 99999.0 x0,20 + 99999.0 x0,21 + -1.0 c0,21> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,21 + -1.0 c0,21 + 99999.0 x1,21 + 99999.0 x2,21> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x0,22 + -1.0 c0,22> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x0,22 + -1.0 c0,22> >= -99999.0
#    (1) : <gurobi.LinExpr: x0,20 + -1.0 c0,22> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x0,20 + 99999.0 x0,21 + 99999.0 x0,22 + -1.0 c0,22> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x0,21 + -1.0 c0,22> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x0,21 + 99999.0 x0,22 + -1.0 c0,22> >= -99999.0
#    (3) : <gurobi.LinExpr: c0,22> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x0,20 + 99999.0 x0,21 + 99999.0 x0,22 + -1.0 c0,22> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,22 + -1.0 c0,22 + 99999.0 x1,22 + 99999.0 x2,22> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x0,23 + -1.0 c0,23> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x0,23 + -1.0 c0,23> >= -99999.0
#    (1) : <gurobi.LinExpr: x0,21 + -1.0 c0,23> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x0,21 + 99999.0 x0,22 + 99999.0 x0,23 + -1.0 c0,23> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x0,22 + -1.0 c0,23> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x0,22 + 99999.0 x0,23 + -1.0 c0,23> >= -99999.0
#    (3) : <gurobi.LinExpr: c0,23> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x0,21 + 99999.0 x0,22 + 99999.0 x0,23 + -1.0 c0,23> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,23 + -1.0 c0,23 + 99999.0 x1,23 + 99999.0 x2,23> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x0,24 + -1.0 c0,24> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x0,24 + -1.0 c0,24> >= -99999.0
#    (1) : <gurobi.LinExpr: x0,22 + -1.0 c0,24> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x0,22 + 99999.0 x0,23 + 99999.0 x0,24 + -1.0 c0,24> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x0,23 + -1.0 c0,24> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x0,23 + 99999.0 x0,24 + -1.0 c0,24> >= -99999.0
#    (3) : <gurobi.LinExpr: c0,24> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x0,22 + 99999.0 x0,23 + 99999.0 x0,24 + -1.0 c0,24> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,24 + -1.0 c0,24 + 99999.0 x1,24 + 99999.0 x2,24> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x0,25 + -1.0 c0,25> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x0,25 + -1.0 c0,25> >= -99999.0
#    (1) : <gurobi.LinExpr: x0,23 + -1.0 c0,25> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x0,23 + 99999.0 x0,24 + 99999.0 x0,25 + -1.0 c0,25> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x0,24 + -1.0 c0,25> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x0,24 + 99999.0 x0,25 + -1.0 c0,25> >= -99999.0
#    (3) : <gurobi.LinExpr: c0,25> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x0,23 + 99999.0 x0,24 + 99999.0 x0,25 + -1.0 c0,25> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,25 + -1.0 c0,25 + 99999.0 x1,25 + 99999.0 x2,25> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x0,26 + -1.0 c0,26> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x0,26 + -1.0 c0,26> >= -99999.0
#    (1) : <gurobi.LinExpr: x0,24 + -1.0 c0,26> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x0,24 + 99999.0 x0,25 + 99999.0 x0,26 + -1.0 c0,26> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x0,25 + -1.0 c0,26> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x0,25 + 99999.0 x0,26 + -1.0 c0,26> >= -99999.0
#    (3) : <gurobi.LinExpr: c0,26> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x0,24 + 99999.0 x0,25 + 99999.0 x0,26 + -1.0 c0,26> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,26 + -1.0 c0,26 + 99999.0 x1,26 + 99999.0 x2,26> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x0,27 + -1.0 c0,27> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x0,27 + -1.0 c0,27> >= -99999.0
#    (1) : <gurobi.LinExpr: x0,25 + -1.0 c0,27> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x0,25 + 99999.0 x0,26 + 99999.0 x0,27 + -1.0 c0,27> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x0,26 + -1.0 c0,27> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x0,26 + 99999.0 x0,27 + -1.0 c0,27> >= -99999.0
#    (3) : <gurobi.LinExpr: c0,27> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x0,25 + 99999.0 x0,26 + 99999.0 x0,27 + -1.0 c0,27> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,27 + -1.0 c0,27 + 99999.0 x1,27 + 99999.0 x2,27> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x0,28 + -1.0 c0,28> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x0,28 + -1.0 c0,28> >= -99999.0
#    (1) : <gurobi.LinExpr: x0,26 + -1.0 c0,28> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x0,26 + 99999.0 x0,27 + 99999.0 x0,28 + -1.0 c0,28> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x0,27 + -1.0 c0,28> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x0,27 + 99999.0 x0,28 + -1.0 c0,28> >= -99999.0
#    (3) : <gurobi.LinExpr: c0,28> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x0,26 + 99999.0 x0,27 + 99999.0 x0,28 + -1.0 c0,28> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,28 + -1.0 c0,28 + 99999.0 x1,28 + 99999.0 x2,28> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x0,29 + -1.0 c0,29> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x0,29 + -1.0 c0,29> >= -99999.0
#    (1) : <gurobi.LinExpr: x0,27 + -1.0 c0,29> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x0,27 + 99999.0 x0,28 + 99999.0 x0,29 + -1.0 c0,29> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x0,28 + -1.0 c0,29> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x0,28 + 99999.0 x0,29 + -1.0 c0,29> >= -99999.0
#    (3) : <gurobi.LinExpr: c0,29> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x0,27 + 99999.0 x0,28 + 99999.0 x0,29 + -1.0 c0,29> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,29 + -1.0 c0,29 + 99999.0 x1,29 + 99999.0 x2,29> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x0,30 + -1.0 c0,30> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x0,30 + -1.0 c0,30> >= -99999.0
#    (1) : <gurobi.LinExpr: x0,28 + -1.0 c0,30> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x0,28 + 99999.0 x0,29 + 99999.0 x0,30 + -1.0 c0,30> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x0,29 + -1.0 c0,30> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x0,29 + 99999.0 x0,30 + -1.0 c0,30> >= -99999.0
#    (3) : <gurobi.LinExpr: c0,30> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x0,28 + 99999.0 x0,29 + 99999.0 x0,30 + -1.0 c0,30> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,30 + -1.0 c0,30 + 99999.0 x1,30 + 99999.0 x2,30> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x0,31 + -1.0 c0,31> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x0,31 + -1.0 c0,31> >= -99999.0
#    (1) : <gurobi.LinExpr: x0,29 + -1.0 c0,31> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x0,29 + 99999.0 x0,30 + 99999.0 x0,31 + -1.0 c0,31> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x0,30 + -1.0 c0,31> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x0,30 + 99999.0 x0,31 + -1.0 c0,31> >= -99999.0
#    (3) : <gurobi.LinExpr: c0,31> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x0,29 + 99999.0 x0,30 + 99999.0 x0,31 + -1.0 c0,31> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,31 + -1.0 c0,31 + 99999.0 x1,31 + 99999.0 x2,31> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x0,32 + -1.0 c0,32> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x0,32 + -1.0 c0,32> >= -99999.0
#    (1) : <gurobi.LinExpr: x0,30 + -1.0 c0,32> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x0,30 + 99999.0 x0,31 + 99999.0 x0,32 + -1.0 c0,32> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x0,31 + -1.0 c0,32> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x0,31 + 99999.0 x0,32 + -1.0 c0,32> >= -99999.0
#    (3) : <gurobi.LinExpr: c0,32> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x0,30 + 99999.0 x0,31 + 99999.0 x0,32 + -1.0 c0,32> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,32 + -1.0 c0,32 + 99999.0 x1,32 + 99999.0 x2,32> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x0,33 + -1.0 c0,33> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x0,33 + -1.0 c0,33> >= -99999.0
#    (1) : <gurobi.LinExpr: x0,31 + -1.0 c0,33> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x0,31 + 99999.0 x0,32 + 99999.0 x0,33 + -1.0 c0,33> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x0,32 + -1.0 c0,33> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x0,32 + 99999.0 x0,33 + -1.0 c0,33> >= -99999.0
#    (3) : <gurobi.LinExpr: c0,33> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x0,31 + 99999.0 x0,32 + 99999.0 x0,33 + -1.0 c0,33> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,33 + -1.0 c0,33 + 99999.0 x1,33 + 99999.0 x2,33> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x0,34 + -1.0 c0,34> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x0,34 + -1.0 c0,34> >= -99999.0
#    (1) : <gurobi.LinExpr: x0,32 + -1.0 c0,34> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x0,32 + 99999.0 x0,33 + 99999.0 x0,34 + -1.0 c0,34> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x0,33 + -1.0 c0,34> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x0,33 + 99999.0 x0,34 + -1.0 c0,34> >= -99999.0
#    (3) : <gurobi.LinExpr: c0,34> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x0,32 + 99999.0 x0,33 + 99999.0 x0,34 + -1.0 c0,34> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,34 + -1.0 c0,34 + 99999.0 x1,34 + 99999.0 x2,34> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x0,35 + -1.0 c0,35> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x0,35 + -1.0 c0,35> >= -99999.0
#    (1) : <gurobi.LinExpr: x0,33 + -1.0 c0,35> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x0,33 + 99999.0 x0,34 + 99999.0 x0,35 + -1.0 c0,35> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x0,34 + -1.0 c0,35> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x0,34 + 99999.0 x0,35 + -1.0 c0,35> >= -99999.0
#    (3) : <gurobi.LinExpr: c0,35> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x0,33 + 99999.0 x0,34 + 99999.0 x0,35 + -1.0 c0,35> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,35 + -1.0 c0,35 + 99999.0 x1,35 + 99999.0 x2,35> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x0,36 + -1.0 c0,36> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x0,36 + -1.0 c0,36> >= -99999.0
#    (1) : <gurobi.LinExpr: x0,34 + -1.0 c0,36> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x0,34 + 99999.0 x0,35 + 99999.0 x0,36 + -1.0 c0,36> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x0,35 + -1.0 c0,36> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x0,35 + 99999.0 x0,36 + -1.0 c0,36> >= -99999.0
#    (3) : <gurobi.LinExpr: c0,36> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x0,34 + 99999.0 x0,35 + 99999.0 x0,36 + -1.0 c0,36> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,36 + -1.0 c0,36 + 99999.0 x1,36 + 99999.0 x2,36> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x0,37 + -1.0 c0,37> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x0,37 + -1.0 c0,37> >= -99999.0
#    (1) : <gurobi.LinExpr: x0,35 + -1.0 c0,37> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x0,35 + 99999.0 x0,36 + 99999.0 x0,37 + -1.0 c0,37> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x0,36 + -1.0 c0,37> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x0,36 + 99999.0 x0,37 + -1.0 c0,37> >= -99999.0
#    (3) : <gurobi.LinExpr: c0,37> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x0,35 + 99999.0 x0,36 + 99999.0 x0,37 + -1.0 c0,37> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,37 + -1.0 c0,37 + 99999.0 x1,37 + 99999.0 x2,37> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x0,38 + -1.0 c0,38> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x0,38 + -1.0 c0,38> >= -99999.0
#    (1) : <gurobi.LinExpr: x0,36 + -1.0 c0,38> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x0,36 + 99999.0 x0,37 + 99999.0 x0,38 + -1.0 c0,38> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x0,37 + -1.0 c0,38> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x0,37 + 99999.0 x0,38 + -1.0 c0,38> >= -99999.0
#    (3) : <gurobi.LinExpr: c0,38> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x0,36 + 99999.0 x0,37 + 99999.0 x0,38 + -1.0 c0,38> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,38 + -1.0 c0,38 + 99999.0 x1,38 + 99999.0 x2,38> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x0,39 + -1.0 c0,39> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x0,39 + -1.0 c0,39> >= -99999.0
#    (1) : <gurobi.LinExpr: x0,37 + -1.0 c0,39> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x0,37 + 99999.0 x0,38 + 99999.0 x0,39 + -1.0 c0,39> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x0,38 + -1.0 c0,39> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x0,38 + 99999.0 x0,39 + -1.0 c0,39> >= -99999.0
#    (3) : <gurobi.LinExpr: c0,39> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x0,37 + 99999.0 x0,38 + 99999.0 x0,39 + -1.0 c0,39> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,39 + -1.0 c0,39 + 99999.0 x1,39 + 99999.0 x2,39> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x1,0 + -1.0 c1,0> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x1,0 + -1.0 c1,0> >= -99999.0
#    (3) : <gurobi.LinExpr: c1,0> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x1,0 + -1.0 c1,0> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,0 + 99999.0 x1,0 + -1.0 c1,0 + 99999.0 x2,0> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x1,1 + -1.0 c1,1> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x1,1 + -1.0 c1,1> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x1,0 + -1.0 c1,1> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x1,0 + 99999.0 x1,1 + -1.0 c1,1> >= -99999.0
#    (3) : <gurobi.LinExpr: c1,1> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x1,0 + 99999.0 x1,1 + -1.0 c1,1> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,1 + 99999.0 x1,1 + -1.0 c1,1 + 99999.0 x2,1> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x1,2 + -1.0 c1,2> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x1,2 + -1.0 c1,2> >= -99999.0
#    (1) : <gurobi.LinExpr: x1,0 + -1.0 c1,2> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x1,0 + 99999.0 x1,1 + 99999.0 x1,2 + -1.0 c1,2> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x1,1 + -1.0 c1,2> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x1,1 + 99999.0 x1,2 + -1.0 c1,2> >= -99999.0
#    (3) : <gurobi.LinExpr: c1,2> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x1,0 + 99999.0 x1,1 + 99999.0 x1,2 + -1.0 c1,2> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,2 + 99999.0 x1,2 + -1.0 c1,2 + 99999.0 x2,2> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x1,3 + -1.0 c1,3> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x1,3 + -1.0 c1,3> >= -99999.0
#    (1) : <gurobi.LinExpr: x1,1 + -1.0 c1,3> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x1,1 + 99999.0 x1,2 + 99999.0 x1,3 + -1.0 c1,3> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x1,2 + -1.0 c1,3> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x1,2 + 99999.0 x1,3 + -1.0 c1,3> >= -99999.0
#    (3) : <gurobi.LinExpr: c1,3> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x1,1 + 99999.0 x1,2 + 99999.0 x1,3 + -1.0 c1,3> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,3 + 99999.0 x1,3 + -1.0 c1,3 + 99999.0 x2,3> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x1,4 + -1.0 c1,4> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x1,4 + -1.0 c1,4> >= -99999.0
#    (1) : <gurobi.LinExpr: x1,2 + -1.0 c1,4> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x1,2 + 99999.0 x1,3 + 99999.0 x1,4 + -1.0 c1,4> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x1,3 + -1.0 c1,4> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x1,3 + 99999.0 x1,4 + -1.0 c1,4> >= -99999.0
#    (3) : <gurobi.LinExpr: c1,4> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x1,2 + 99999.0 x1,3 + 99999.0 x1,4 + -1.0 c1,4> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,4 + 99999.0 x1,4 + -1.0 c1,4 + 99999.0 x2,4> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x1,5 + -1.0 c1,5> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x1,5 + -1.0 c1,5> >= -99999.0
#    (1) : <gurobi.LinExpr: x1,3 + -1.0 c1,5> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x1,3 + 99999.0 x1,4 + 99999.0 x1,5 + -1.0 c1,5> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x1,4 + -1.0 c1,5> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x1,4 + 99999.0 x1,5 + -1.0 c1,5> >= -99999.0
#    (3) : <gurobi.LinExpr: c1,5> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x1,3 + 99999.0 x1,4 + 99999.0 x1,5 + -1.0 c1,5> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,5 + 99999.0 x1,5 + -1.0 c1,5 + 99999.0 x2,5> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x1,6 + -1.0 c1,6> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x1,6 + -1.0 c1,6> >= -99999.0
#    (1) : <gurobi.LinExpr: x1,4 + -1.0 c1,6> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x1,4 + 99999.0 x1,5 + 99999.0 x1,6 + -1.0 c1,6> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x1,5 + -1.0 c1,6> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x1,5 + 99999.0 x1,6 + -1.0 c1,6> >= -99999.0
#    (3) : <gurobi.LinExpr: c1,6> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x1,4 + 99999.0 x1,5 + 99999.0 x1,6 + -1.0 c1,6> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,6 + 99999.0 x1,6 + -1.0 c1,6 + 99999.0 x2,6> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x1,7 + -1.0 c1,7> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x1,7 + -1.0 c1,7> >= -99999.0
#    (1) : <gurobi.LinExpr: x1,5 + -1.0 c1,7> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x1,5 + 99999.0 x1,6 + 99999.0 x1,7 + -1.0 c1,7> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x1,6 + -1.0 c1,7> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x1,6 + 99999.0 x1,7 + -1.0 c1,7> >= -99999.0
#    (3) : <gurobi.LinExpr: c1,7> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x1,5 + 99999.0 x1,6 + 99999.0 x1,7 + -1.0 c1,7> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,7 + 99999.0 x1,7 + -1.0 c1,7 + 99999.0 x2,7> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x1,8 + -1.0 c1,8> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x1,8 + -1.0 c1,8> >= -99999.0
#    (1) : <gurobi.LinExpr: x1,6 + -1.0 c1,8> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x1,6 + 99999.0 x1,7 + 99999.0 x1,8 + -1.0 c1,8> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x1,7 + -1.0 c1,8> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x1,7 + 99999.0 x1,8 + -1.0 c1,8> >= -99999.0
#    (3) : <gurobi.LinExpr: c1,8> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x1,6 + 99999.0 x1,7 + 99999.0 x1,8 + -1.0 c1,8> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,8 + 99999.0 x1,8 + -1.0 c1,8 + 99999.0 x2,8> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x1,9 + -1.0 c1,9> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x1,9 + -1.0 c1,9> >= -99999.0
#    (1) : <gurobi.LinExpr: x1,7 + -1.0 c1,9> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x1,7 + 99999.0 x1,8 + 99999.0 x1,9 + -1.0 c1,9> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x1,8 + -1.0 c1,9> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x1,8 + 99999.0 x1,9 + -1.0 c1,9> >= -99999.0
#    (3) : <gurobi.LinExpr: c1,9> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x1,7 + 99999.0 x1,8 + 99999.0 x1,9 + -1.0 c1,9> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,9 + 99999.0 x1,9 + -1.0 c1,9 + 99999.0 x2,9> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x1,10 + -1.0 c1,10> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x1,10 + -1.0 c1,10> >= -99999.0
#    (1) : <gurobi.LinExpr: x1,8 + -1.0 c1,10> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x1,8 + 99999.0 x1,9 + 99999.0 x1,10 + -1.0 c1,10> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x1,9 + -1.0 c1,10> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x1,9 + 99999.0 x1,10 + -1.0 c1,10> >= -99999.0
#    (3) : <gurobi.LinExpr: c1,10> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x1,8 + 99999.0 x1,9 + 99999.0 x1,10 + -1.0 c1,10> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,10 + 99999.0 x1,10 + -1.0 c1,10 + 99999.0 x2,10> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x1,11 + -1.0 c1,11> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x1,11 + -1.0 c1,11> >= -99999.0
#    (1) : <gurobi.LinExpr: x1,9 + -1.0 c1,11> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x1,9 + 99999.0 x1,10 + 99999.0 x1,11 + -1.0 c1,11> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x1,10 + -1.0 c1,11> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x1,10 + 99999.0 x1,11 + -1.0 c1,11> >= -99999.0
#    (3) : <gurobi.LinExpr: c1,11> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x1,9 + 99999.0 x1,10 + 99999.0 x1,11 + -1.0 c1,11> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,11 + 99999.0 x1,11 + -1.0 c1,11 + 99999.0 x2,11> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x1,12 + -1.0 c1,12> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x1,12 + -1.0 c1,12> >= -99999.0
#    (1) : <gurobi.LinExpr: x1,10 + -1.0 c1,12> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x1,10 + 99999.0 x1,11 + 99999.0 x1,12 + -1.0 c1,12> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x1,11 + -1.0 c1,12> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x1,11 + 99999.0 x1,12 + -1.0 c1,12> >= -99999.0
#    (3) : <gurobi.LinExpr: c1,12> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x1,10 + 99999.0 x1,11 + 99999.0 x1,12 + -1.0 c1,12> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,12 + 99999.0 x1,12 + -1.0 c1,12 + 99999.0 x2,12> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x1,13 + -1.0 c1,13> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x1,13 + -1.0 c1,13> >= -99999.0
#    (1) : <gurobi.LinExpr: x1,11 + -1.0 c1,13> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x1,11 + 99999.0 x1,12 + 99999.0 x1,13 + -1.0 c1,13> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x1,12 + -1.0 c1,13> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x1,12 + 99999.0 x1,13 + -1.0 c1,13> >= -99999.0
#    (3) : <gurobi.LinExpr: c1,13> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x1,11 + 99999.0 x1,12 + 99999.0 x1,13 + -1.0 c1,13> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,13 + 99999.0 x1,13 + -1.0 c1,13 + 99999.0 x2,13> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x1,14 + -1.0 c1,14> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x1,14 + -1.0 c1,14> >= -99999.0
#    (1) : <gurobi.LinExpr: x1,12 + -1.0 c1,14> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x1,12 + 99999.0 x1,13 + 99999.0 x1,14 + -1.0 c1,14> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x1,13 + -1.0 c1,14> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x1,13 + 99999.0 x1,14 + -1.0 c1,14> >= -99999.0
#    (3) : <gurobi.LinExpr: c1,14> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x1,12 + 99999.0 x1,13 + 99999.0 x1,14 + -1.0 c1,14> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,14 + 99999.0 x1,14 + -1.0 c1,14 + 99999.0 x2,14> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x1,15 + -1.0 c1,15> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x1,15 + -1.0 c1,15> >= -99999.0
#    (1) : <gurobi.LinExpr: x1,13 + -1.0 c1,15> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x1,13 + 99999.0 x1,14 + 99999.0 x1,15 + -1.0 c1,15> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x1,14 + -1.0 c1,15> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x1,14 + 99999.0 x1,15 + -1.0 c1,15> >= -99999.0
#    (3) : <gurobi.LinExpr: c1,15> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x1,13 + 99999.0 x1,14 + 99999.0 x1,15 + -1.0 c1,15> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,15 + 99999.0 x1,15 + -1.0 c1,15 + 99999.0 x2,15> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x1,16 + -1.0 c1,16> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x1,16 + -1.0 c1,16> >= -99999.0
#    (1) : <gurobi.LinExpr: x1,14 + -1.0 c1,16> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x1,14 + 99999.0 x1,15 + 99999.0 x1,16 + -1.0 c1,16> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x1,15 + -1.0 c1,16> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x1,15 + 99999.0 x1,16 + -1.0 c1,16> >= -99999.0
#    (3) : <gurobi.LinExpr: c1,16> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x1,14 + 99999.0 x1,15 + 99999.0 x1,16 + -1.0 c1,16> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,16 + 99999.0 x1,16 + -1.0 c1,16 + 99999.0 x2,16> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x1,17 + -1.0 c1,17> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x1,17 + -1.0 c1,17> >= -99999.0
#    (1) : <gurobi.LinExpr: x1,15 + -1.0 c1,17> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x1,15 + 99999.0 x1,16 + 99999.0 x1,17 + -1.0 c1,17> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x1,16 + -1.0 c1,17> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x1,16 + 99999.0 x1,17 + -1.0 c1,17> >= -99999.0
#    (3) : <gurobi.LinExpr: c1,17> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x1,15 + 99999.0 x1,16 + 99999.0 x1,17 + -1.0 c1,17> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,17 + 99999.0 x1,17 + -1.0 c1,17 + 99999.0 x2,17> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x1,18 + -1.0 c1,18> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x1,18 + -1.0 c1,18> >= -99999.0
#    (1) : <gurobi.LinExpr: x1,16 + -1.0 c1,18> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x1,16 + 99999.0 x1,17 + 99999.0 x1,18 + -1.0 c1,18> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x1,17 + -1.0 c1,18> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x1,17 + 99999.0 x1,18 + -1.0 c1,18> >= -99999.0
#    (3) : <gurobi.LinExpr: c1,18> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x1,16 + 99999.0 x1,17 + 99999.0 x1,18 + -1.0 c1,18> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,18 + 99999.0 x1,18 + -1.0 c1,18 + 99999.0 x2,18> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x1,19 + -1.0 c1,19> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x1,19 + -1.0 c1,19> >= -99999.0
#    (1) : <gurobi.LinExpr: x1,17 + -1.0 c1,19> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x1,17 + 99999.0 x1,18 + 99999.0 x1,19 + -1.0 c1,19> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x1,18 + -1.0 c1,19> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x1,18 + 99999.0 x1,19 + -1.0 c1,19> >= -99999.0
#    (3) : <gurobi.LinExpr: c1,19> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x1,17 + 99999.0 x1,18 + 99999.0 x1,19 + -1.0 c1,19> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,19 + 99999.0 x1,19 + -1.0 c1,19 + 99999.0 x2,19> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x1,20 + -1.0 c1,20> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x1,20 + -1.0 c1,20> >= -99999.0
#    (1) : <gurobi.LinExpr: x1,18 + -1.0 c1,20> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x1,18 + 99999.0 x1,19 + 99999.0 x1,20 + -1.0 c1,20> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x1,19 + -1.0 c1,20> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x1,19 + 99999.0 x1,20 + -1.0 c1,20> >= -99999.0
#    (3) : <gurobi.LinExpr: c1,20> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x1,18 + 99999.0 x1,19 + 99999.0 x1,20 + -1.0 c1,20> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,20 + 99999.0 x1,20 + -1.0 c1,20 + 99999.0 x2,20> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x1,21 + -1.0 c1,21> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x1,21 + -1.0 c1,21> >= -99999.0
#    (1) : <gurobi.LinExpr: x1,19 + -1.0 c1,21> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x1,19 + 99999.0 x1,20 + 99999.0 x1,21 + -1.0 c1,21> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x1,20 + -1.0 c1,21> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x1,20 + 99999.0 x1,21 + -1.0 c1,21> >= -99999.0
#    (3) : <gurobi.LinExpr: c1,21> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x1,19 + 99999.0 x1,20 + 99999.0 x1,21 + -1.0 c1,21> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,21 + 99999.0 x1,21 + -1.0 c1,21 + 99999.0 x2,21> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x1,22 + -1.0 c1,22> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x1,22 + -1.0 c1,22> >= -99999.0
#    (1) : <gurobi.LinExpr: x1,20 + -1.0 c1,22> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x1,20 + 99999.0 x1,21 + 99999.0 x1,22 + -1.0 c1,22> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x1,21 + -1.0 c1,22> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x1,21 + 99999.0 x1,22 + -1.0 c1,22> >= -99999.0
#    (3) : <gurobi.LinExpr: c1,22> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x1,20 + 99999.0 x1,21 + 99999.0 x1,22 + -1.0 c1,22> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,22 + 99999.0 x1,22 + -1.0 c1,22 + 99999.0 x2,22> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x1,23 + -1.0 c1,23> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x1,23 + -1.0 c1,23> >= -99999.0
#    (1) : <gurobi.LinExpr: x1,21 + -1.0 c1,23> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x1,21 + 99999.0 x1,22 + 99999.0 x1,23 + -1.0 c1,23> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x1,22 + -1.0 c1,23> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x1,22 + 99999.0 x1,23 + -1.0 c1,23> >= -99999.0
#    (3) : <gurobi.LinExpr: c1,23> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x1,21 + 99999.0 x1,22 + 99999.0 x1,23 + -1.0 c1,23> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,23 + 99999.0 x1,23 + -1.0 c1,23 + 99999.0 x2,23> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x1,24 + -1.0 c1,24> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x1,24 + -1.0 c1,24> >= -99999.0
#    (1) : <gurobi.LinExpr: x1,22 + -1.0 c1,24> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x1,22 + 99999.0 x1,23 + 99999.0 x1,24 + -1.0 c1,24> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x1,23 + -1.0 c1,24> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x1,23 + 99999.0 x1,24 + -1.0 c1,24> >= -99999.0
#    (3) : <gurobi.LinExpr: c1,24> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x1,22 + 99999.0 x1,23 + 99999.0 x1,24 + -1.0 c1,24> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,24 + 99999.0 x1,24 + -1.0 c1,24 + 99999.0 x2,24> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x1,25 + -1.0 c1,25> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x1,25 + -1.0 c1,25> >= -99999.0
#    (1) : <gurobi.LinExpr: x1,23 + -1.0 c1,25> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x1,23 + 99999.0 x1,24 + 99999.0 x1,25 + -1.0 c1,25> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x1,24 + -1.0 c1,25> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x1,24 + 99999.0 x1,25 + -1.0 c1,25> >= -99999.0
#    (3) : <gurobi.LinExpr: c1,25> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x1,23 + 99999.0 x1,24 + 99999.0 x1,25 + -1.0 c1,25> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,25 + 99999.0 x1,25 + -1.0 c1,25 + 99999.0 x2,25> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x1,26 + -1.0 c1,26> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x1,26 + -1.0 c1,26> >= -99999.0
#    (1) : <gurobi.LinExpr: x1,24 + -1.0 c1,26> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x1,24 + 99999.0 x1,25 + 99999.0 x1,26 + -1.0 c1,26> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x1,25 + -1.0 c1,26> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x1,25 + 99999.0 x1,26 + -1.0 c1,26> >= -99999.0
#    (3) : <gurobi.LinExpr: c1,26> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x1,24 + 99999.0 x1,25 + 99999.0 x1,26 + -1.0 c1,26> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,26 + 99999.0 x1,26 + -1.0 c1,26 + 99999.0 x2,26> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x1,27 + -1.0 c1,27> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x1,27 + -1.0 c1,27> >= -99999.0
#    (1) : <gurobi.LinExpr: x1,25 + -1.0 c1,27> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x1,25 + 99999.0 x1,26 + 99999.0 x1,27 + -1.0 c1,27> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x1,26 + -1.0 c1,27> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x1,26 + 99999.0 x1,27 + -1.0 c1,27> >= -99999.0
#    (3) : <gurobi.LinExpr: c1,27> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x1,25 + 99999.0 x1,26 + 99999.0 x1,27 + -1.0 c1,27> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,27 + 99999.0 x1,27 + -1.0 c1,27 + 99999.0 x2,27> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x1,28 + -1.0 c1,28> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x1,28 + -1.0 c1,28> >= -99999.0
#    (1) : <gurobi.LinExpr: x1,26 + -1.0 c1,28> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x1,26 + 99999.0 x1,27 + 99999.0 x1,28 + -1.0 c1,28> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x1,27 + -1.0 c1,28> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x1,27 + 99999.0 x1,28 + -1.0 c1,28> >= -99999.0
#    (3) : <gurobi.LinExpr: c1,28> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x1,26 + 99999.0 x1,27 + 99999.0 x1,28 + -1.0 c1,28> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,28 + 99999.0 x1,28 + -1.0 c1,28 + 99999.0 x2,28> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x1,29 + -1.0 c1,29> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x1,29 + -1.0 c1,29> >= -99999.0
#    (1) : <gurobi.LinExpr: x1,27 + -1.0 c1,29> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x1,27 + 99999.0 x1,28 + 99999.0 x1,29 + -1.0 c1,29> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x1,28 + -1.0 c1,29> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x1,28 + 99999.0 x1,29 + -1.0 c1,29> >= -99999.0
#    (3) : <gurobi.LinExpr: c1,29> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x1,27 + 99999.0 x1,28 + 99999.0 x1,29 + -1.0 c1,29> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,29 + 99999.0 x1,29 + -1.0 c1,29 + 99999.0 x2,29> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x1,30 + -1.0 c1,30> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x1,30 + -1.0 c1,30> >= -99999.0
#    (1) : <gurobi.LinExpr: x1,28 + -1.0 c1,30> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x1,28 + 99999.0 x1,29 + 99999.0 x1,30 + -1.0 c1,30> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x1,29 + -1.0 c1,30> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x1,29 + 99999.0 x1,30 + -1.0 c1,30> >= -99999.0
#    (3) : <gurobi.LinExpr: c1,30> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x1,28 + 99999.0 x1,29 + 99999.0 x1,30 + -1.0 c1,30> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,30 + 99999.0 x1,30 + -1.0 c1,30 + 99999.0 x2,30> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x1,31 + -1.0 c1,31> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x1,31 + -1.0 c1,31> >= -99999.0
#    (1) : <gurobi.LinExpr: x1,29 + -1.0 c1,31> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x1,29 + 99999.0 x1,30 + 99999.0 x1,31 + -1.0 c1,31> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x1,30 + -1.0 c1,31> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x1,30 + 99999.0 x1,31 + -1.0 c1,31> >= -99999.0
#    (3) : <gurobi.LinExpr: c1,31> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x1,29 + 99999.0 x1,30 + 99999.0 x1,31 + -1.0 c1,31> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,31 + 99999.0 x1,31 + -1.0 c1,31 + 99999.0 x2,31> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x1,32 + -1.0 c1,32> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x1,32 + -1.0 c1,32> >= -99999.0
#    (1) : <gurobi.LinExpr: x1,30 + -1.0 c1,32> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x1,30 + 99999.0 x1,31 + 99999.0 x1,32 + -1.0 c1,32> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x1,31 + -1.0 c1,32> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x1,31 + 99999.0 x1,32 + -1.0 c1,32> >= -99999.0
#    (3) : <gurobi.LinExpr: c1,32> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x1,30 + 99999.0 x1,31 + 99999.0 x1,32 + -1.0 c1,32> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,32 + 99999.0 x1,32 + -1.0 c1,32 + 99999.0 x2,32> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x1,33 + -1.0 c1,33> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x1,33 + -1.0 c1,33> >= -99999.0
#    (1) : <gurobi.LinExpr: x1,31 + -1.0 c1,33> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x1,31 + 99999.0 x1,32 + 99999.0 x1,33 + -1.0 c1,33> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x1,32 + -1.0 c1,33> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x1,32 + 99999.0 x1,33 + -1.0 c1,33> >= -99999.0
#    (3) : <gurobi.LinExpr: c1,33> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x1,31 + 99999.0 x1,32 + 99999.0 x1,33 + -1.0 c1,33> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,33 + 99999.0 x1,33 + -1.0 c1,33 + 99999.0 x2,33> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x1,34 + -1.0 c1,34> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x1,34 + -1.0 c1,34> >= -99999.0
#    (1) : <gurobi.LinExpr: x1,32 + -1.0 c1,34> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x1,32 + 99999.0 x1,33 + 99999.0 x1,34 + -1.0 c1,34> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x1,33 + -1.0 c1,34> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x1,33 + 99999.0 x1,34 + -1.0 c1,34> >= -99999.0
#    (3) : <gurobi.LinExpr: c1,34> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x1,32 + 99999.0 x1,33 + 99999.0 x1,34 + -1.0 c1,34> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,34 + 99999.0 x1,34 + -1.0 c1,34 + 99999.0 x2,34> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x1,35 + -1.0 c1,35> <= 0.0
# ...
#    (3) : <gurobi.LinExpr: c2,36> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x2,34 + 99999.0 x2,35 + 99999.0 x2,36 + -1.0 c2,36> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,36 + 99999.0 x1,36 + 99999.0 x2,36 + -1.0 c2,36> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x2,37 + -1.0 c2,37> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x2,37 + -1.0 c2,37> >= -99999.0
#    (1) : <gurobi.LinExpr: x2,35 + -1.0 c2,37> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x2,35 + 99999.0 x2,36 + 99999.0 x2,37 + -1.0 c2,37> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x2,36 + -1.0 c2,37> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x2,36 + 99999.0 x2,37 + -1.0 c2,37> >= -99999.0
#    (3) : <gurobi.LinExpr: c2,37> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x2,35 + 99999.0 x2,36 + 99999.0 x2,37 + -1.0 c2,37> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,37 + 99999.0 x1,37 + 99999.0 x2,37 + -1.0 c2,37> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x2,38 + -1.0 c2,38> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x2,38 + -1.0 c2,38> >= -99999.0
#    (1) : <gurobi.LinExpr: x2,36 + -1.0 c2,38> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x2,36 + 99999.0 x2,37 + 99999.0 x2,38 + -1.0 c2,38> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x2,37 + -1.0 c2,38> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x2,37 + 99999.0 x2,38 + -1.0 c2,38> >= -99999.0
#    (3) : <gurobi.LinExpr: c2,38> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x2,36 + 99999.0 x2,37 + 99999.0 x2,38 + -1.0 c2,38> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,38 + 99999.0 x1,38 + 99999.0 x2,38 + -1.0 c2,38> >= 0.0
#    (1) : <gurobi.LinExpr: 3.0 x2,39 + -1.0 c2,39> <= 0.0
#    (2) : <gurobi.LinExpr: -99996.0 x2,39 + -1.0 c2,39> >= -99999.0
#    (1) : <gurobi.LinExpr: x2,37 + -1.0 c2,39> <= 0.0
#    (2) : <gurobi.LinExpr: -99998.0 x2,37 + 99999.0 x2,38 + 99999.0 x2,39 + -1.0 c2,39> >= -99999.0
#    (1) : <gurobi.LinExpr: 2.0 x2,38 + -1.0 c2,39> <= 0.0
#    (2) : <gurobi.LinExpr: -99997.0 x2,38 + 99999.0 x2,39 + -1.0 c2,39> >= -99999.0
#    (3) : <gurobi.LinExpr: c2,39> >= 0.0
#    (3) : <gurobi.LinExpr: 99999.0 x2,37 + 99999.0 x2,38 + 99999.0 x2,39 + -1.0 c2,39> >= 0.0
#    (test) : <gurobi.LinExpr: 99999.0 x0,39 + 99999.0 x1,39 + 99999.0 x2,39 + -1.0 c2,39> >= 0.0
#    (4) : <gurobi.LinExpr: c0,0 + c0,1 + c0,2 + c0,3 + c0,4 + c0,5 + c0,6 + c0,7 + c0,8 + c0,9 + c0,10 + c0,11 + c0,12 + c0,13 + c0,14 + c0,15 + c0,16 + c0,17 + c0,18 + c0,19 + c0,20 + c0,21 + c0,22 + c0,23 + c0,24 + c0,25 + c0,26 + c0,27 + c0,28 + c0,29 + c0,30 + c0,31 + c0,32 + c0,33 + c0,34 + c0,35 + c0,36 + c0,37 + c0,38 + c0,39> >= 10.77
#    (4) : <gurobi.LinExpr: c1,0 + c1,1 + c1,2 + c1,3 + c1,4 + c1,5 + c1,6 + c1,7 + c1,8 + c1,9 + c1,10 + c1,11 + c1,12 + c1,13 + c1,14 + c1,15 + c1,16 + c1,17 + c1,18 + c1,19 + c1,20 + c1,21 + c1,22 + c1,23 + c1,24 + c1,25 + c1,26 + c1,27 + c1,28 + c1,29 + c1,30 + c1,31 + c1,32 + c1,33 + c1,34 + c1,35 + c1,36 + c1,37 + c1,38 + c1,39> >= 14.03
#    (4) : <gurobi.LinExpr: c2,0 + c2,1 + c2,2 + c2,3 + c2,4 + c2,5 + c2,6 + c2,7 + c2,8 + c2,9 + c2,10 + c2,11 + c2,12 + c2,13 + c2,14 + c2,15 + c2,16 + c2,17 + c2,18 + c2,19 + c2,20 + c2,21 + c2,22 + c2,23 + c2,24 + c2,25 + c2,26 + c2,27 + c2,28 + c2,29 + c2,30 + c2,31 + c2,32 + c2,33 + c2,34 + c2,35 + c2,36 + c2,37 + c2,38 + c2,39> >= 19.64
#    (5) : <gurobi.LinExpr: x0,0 + x1,0 + x2,0> <= 1.0
#    (5) : <gurobi.LinExpr: x0,1 + x1,1 + x2,1> <= 1.0
#    (5) : <gurobi.LinExpr: x0,2 + x1,2 + x2,2> <= 1.0
#    (5) : <gurobi.LinExpr: x0,3 + x1,3 + x2,3> <= 1.0
#    (5) : <gurobi.LinExpr: x0,4 + x1,4 + x2,4> <= 1.0
#    (5) : <gurobi.LinExpr: x0,5 + x1,5 + x2,5> <= 1.0
#    (5) : <gurobi.LinExpr: x0,6 + x1,6 + x2,6> <= 1.0
#    (5) : <gurobi.LinExpr: x0,7 + x1,7 + x2,7> <= 1.0
#    (5) : <gurobi.LinExpr: x0,8 + x1,8 + x2,8> <= 1.0
#    (5) : <gurobi.LinExpr: x0,9 + x1,9 + x2,9> <= 1.0
#    (5) : <gurobi.LinExpr: x0,10 + x1,10 + x2,10> <= 1.0
#    (5) : <gurobi.LinExpr: x0,11 + x1,11 + x2,11> <= 1.0
#    (5) : <gurobi.LinExpr: x0,12 + x1,12 + x2,12> <= 1.0
#    (5) : <gurobi.LinExpr: x0,13 + x1,13 + x2,13> <= 1.0
#    (5) : <gurobi.LinExpr: x0,14 + x1,14 + x2,14> <= 1.0
#    (5) : <gurobi.LinExpr: x0,15 + x1,15 + x2,15> <= 1.0
#    (5) : <gurobi.LinExpr: x0,16 + x1,16 + x2,16> <= 1.0
#    (5) : <gurobi.LinExpr: x0,17 + x1,17 + x2,17> <= 1.0
#    (5) : <gurobi.LinExpr: x0,18 + x1,18 + x2,18> <= 1.0
#    (5) : <gurobi.LinExpr: x0,19 + x1,19 + x2,19> <= 1.0
#    (5) : <gurobi.LinExpr: x0,20 + x1,20 + x2,20> <= 1.0
#    (5) : <gurobi.LinExpr: x0,21 + x1,21 + x2,21> <= 1.0
#    (5) : <gurobi.LinExpr: x0,22 + x1,22 + x2,22> <= 1.0
#    (5) : <gurobi.LinExpr: x0,23 + x1,23 + x2,23> <= 1.0
#    (5) : <gurobi.LinExpr: x0,24 + x1,24 + x2,24> <= 1.0
#    (5) : <gurobi.LinExpr: x0,25 + x1,25 + x2,25> <= 1.0
#    (5) : <gurobi.LinExpr: x0,26 + x1,26 + x2,26> <= 1.0
#    (5) : <gurobi.LinExpr: x0,27 + x1,27 + x2,27> <= 1.0
#    (5) : <gurobi.LinExpr: x0,28 + x1,28 + x2,28> <= 1.0
#    (5) : <gurobi.LinExpr: x0,29 + x1,29 + x2,29> <= 1.0
#    (5) : <gurobi.LinExpr: x0,30 + x1,30 + x2,30> <= 1.0
#    (5) : <gurobi.LinExpr: x0,31 + x1,31 + x2,31> <= 1.0
#    (5) : <gurobi.LinExpr: x0,32 + x1,32 + x2,32> <= 1.0
#    (5) : <gurobi.LinExpr: x0,33 + x1,33 + x2,33> <= 1.0
#    (5) : <gurobi.LinExpr: x0,34 + x1,34 + x2,34> <= 1.0
#    (5) : <gurobi.LinExpr: x0,35 + x1,35 + x2,35> <= 1.0
#    (5) : <gurobi.LinExpr: x0,36 + x1,36 + x2,36> <= 1.0
#    (5) : <gurobi.LinExpr: x0,37 + x1,37 + x2,37> <= 1.0
#    (5) : <gurobi.LinExpr: x0,38 + x1,38 + x2,38> <= 1.0
#    (5) : <gurobi.LinExpr: x0,39 + x1,39 + x2,39> <= 1.0
#    (6) : <gurobi.LinExpr: -1.0 x0,0 + x0,1 + -1.0 x1,0 + x1,1 + -1.0 x2,0 + x2,1> <= 0.0
#    (6) : <gurobi.LinExpr: -1.0 x0,1 + x0,2 + -1.0 x1,1 + x1,2 + -1.0 x2,1 + x2,2> <= 0.0
#    (6) : <gurobi.LinExpr: -1.0 x0,2 + x0,3 + -1.0 x1,2 + x1,3 + -1.0 x2,2 + x2,3> <= 0.0
#    (6) : <gurobi.LinExpr: -1.0 x0,3 + x0,4 + -1.0 x1,3 + x1,4 + -1.0 x2,3 + x2,4> <= 0.0
#    (6) : <gurobi.LinExpr: -1.0 x0,4 + x0,5 + -1.0 x1,4 + x1,5 + -1.0 x2,4 + x2,5> <= 0.0
#    (6) : <gurobi.LinExpr: -1.0 x0,5 + x0,6 + -1.0 x1,5 + x1,6 + -1.0 x2,5 + x2,6> <= 0.0
#    (6) : <gurobi.LinExpr: -1.0 x0,6 + x0,7 + -1.0 x1,6 + x1,7 + -1.0 x2,6 + x2,7> <= 0.0
#    (6) : <gurobi.LinExpr: -1.0 x0,7 + x0,8 + -1.0 x1,7 + x1,8 + -1.0 x2,7 + x2,8> <= 0.0
#    (6) : <gurobi.LinExpr: -1.0 x0,8 + x0,9 + -1.0 x1,8 + x1,9 + -1.0 x2,8 + x2,9> <= 0.0
#    (6) : <gurobi.LinExpr: -1.0 x0,9 + x0,10 + -1.0 x1,9 + x1,10 + -1.0 x2,9 + x2,10> <= 0.0
#    (6) : <gurobi.LinExpr: -1.0 x0,10 + x0,11 + -1.0 x1,10 + x1,11 + -1.0 x2,10 + x2,11> <= 0.0
#    (6) : <gurobi.LinExpr: -1.0 x0,11 + x0,12 + -1.0 x1,11 + x1,12 + -1.0 x2,11 + x2,12> <= 0.0
#    (6) : <gurobi.LinExpr: -1.0 x0,12 + x0,13 + -1.0 x1,12 + x1,13 + -1.0 x2,12 + x2,13> <= 0.0
#    (6) : <gurobi.LinExpr: -1.0 x0,13 + x0,14 + -1.0 x1,13 + x1,14 + -1.0 x2,13 + x2,14> <= 0.0
#    (6) : <gurobi.LinExpr: -1.0 x0,14 + x0,15 + -1.0 x1,14 + x1,15 + -1.0 x2,14 + x2,15> <= 0.0
#    (6) : <gurobi.LinExpr: -1.0 x0,15 + x0,16 + -1.0 x1,15 + x1,16 + -1.0 x2,15 + x2,16> <= 0.0
#    (6) : <gurobi.LinExpr: -1.0 x0,16 + x0,17 + -1.0 x1,16 + x1,17 + -1.0 x2,16 + x2,17> <= 0.0
#    (6) : <gurobi.LinExpr: -1.0 x0,17 + x0,18 + -1.0 x1,17 + x1,18 + -1.0 x2,17 + x2,18> <= 0.0
#    (6) : <gurobi.LinExpr: -1.0 x0,18 + x0,19 + -1.0 x1,18 + x1,19 + -1.0 x2,18 + x2,19> <= 0.0
#    (6) : <gurobi.LinExpr: -1.0 x0,19 + x0,20 + -1.0 x1,19 + x1,20 + -1.0 x2,19 + x2,20> <= 0.0
#    (6) : <gurobi.LinExpr: -1.0 x0,20 + x0,21 + -1.0 x1,20 + x1,21 + -1.0 x2,20 + x2,21> <= 0.0
#    (6) : <gurobi.LinExpr: -1.0 x0,21 + x0,22 + -1.0 x1,21 + x1,22 + -1.0 x2,21 + x2,22> <= 0.0
#    (6) : <gurobi.LinExpr: -1.0 x0,22 + x0,23 + -1.0 x1,22 + x1,23 + -1.0 x2,22 + x2,23> <= 0.0
#    (6) : <gurobi.LinExpr: -1.0 x0,23 + x0,24 + -1.0 x1,23 + x1,24 + -1.0 x2,23 + x2,24> <= 0.0
#    (6) : <gurobi.LinExpr: -1.0 x0,24 + x0,25 + -1.0 x1,24 + x1,25 + -1.0 x2,24 + x2,25> <= 0.0
#    (6) : <gurobi.LinExpr: -1.0 x0,25 + x0,26 + -1.0 x1,25 + x1,26 + -1.0 x2,25 + x2,26> <= 0.0
#    (6) : <gurobi.LinExpr: -1.0 x0,26 + x0,27 + -1.0 x1,26 + x1,27 + -1.0 x2,26 + x2,27> <= 0.0
#    (6) : <gurobi.LinExpr: -1.0 x0,27 + x0,28 + -1.0 x1,27 + x1,28 + -1.0 x2,27 + x2,28> <= 0.0
#    (6) : <gurobi.LinExpr: -1.0 x0,28 + x0,29 + -1.0 x1,28 + x1,29 + -1.0 x2,28 + x2,29> <= 0.0
#    (6) : <gurobi.LinExpr: -1.0 x0,29 + x0,30 + -1.0 x1,29 + x1,30 + -1.0 x2,29 + x2,30> <= 0.0
#    (6) : <gurobi.LinExpr: -1.0 x0,30 + x0,31 + -1.0 x1,30 + x1,31 + -1.0 x2,30 + x2,31> <= 0.0
#    (6) : <gurobi.LinExpr: -1.0 x0,31 + x0,32 + -1.0 x1,31 + x1,32 + -1.0 x2,31 + x2,32> <= 0.0
#    (6) : <gurobi.LinExpr: -1.0 x0,32 + x0,33 + -1.0 x1,32 + x1,33 + -1.0 x2,32 + x2,33> <= 0.0
#    (6) : <gurobi.LinExpr: -1.0 x0,33 + x0,34 + -1.0 x1,33 + x1,34 + -1.0 x2,33 + x2,34> <= 0.0
#    (6) : <gurobi.LinExpr: -1.0 x0,34 + x0,35 + -1.0 x1,34 + x1,35 + -1.0 x2,34 + x2,35> <= 0.0
#    (6) : <gurobi.LinExpr: -1.0 x0,35 + x0,36 + -1.0 x1,35 + x1,36 + -1.0 x2,35 + x2,36> <= 0.0
#    (6) : <gurobi.LinExpr: -1.0 x0,36 + x0,37 + -1.0 x1,36 + x1,37 + -1.0 x2,36 + x2,37> <= 0.0
#    (6) : <gurobi.LinExpr: -1.0 x0,37 + x0,38 + -1.0 x1,37 + x1,38 + -1.0 x2,37 + x2,38> <= 0.0
#    (6) : <gurobi.LinExpr: -1.0 x0,38 + x0,39 + -1.0 x1,38 + x1,39 + -1.0 x2,38 + x2,39> <= 0.0
#    (7) : <gurobi.LinExpr: x0,0> >= 0.0
#    (7) : <gurobi.LinExpr: x0,1> >= 0.0
#    (7) : <gurobi.LinExpr: x0,2> >= 0.0
#    (7) : <gurobi.LinExpr: x0,3> >= 0.0
#    (7) : <gurobi.LinExpr: x0,4> >= 0.0
#    (7) : <gurobi.LinExpr: x0,5> >= 0.0
#    (7) : <gurobi.LinExpr: x0,6> >= 0.0
#    (7) : <gurobi.LinExpr: x0,7> >= 0.0
#    (7) : <gurobi.LinExpr: x0,8> >= 0.0
#    (7) : <gurobi.LinExpr: x0,9> >= 0.0
#    (7) : <gurobi.LinExpr: x0,10> >= 0.0
#    (7) : <gurobi.LinExpr: x0,11> >= 0.0
#    (7) : <gurobi.LinExpr: x0,12> >= 0.0
#    (7) : <gurobi.LinExpr: x0,13> >= 0.0
#    (7) : <gurobi.LinExpr: x0,14> >= 0.0
#    (7) : <gurobi.LinExpr: x0,15> >= 0.0
#    (7) : <gurobi.LinExpr: x0,16> >= 0.0
#    (7) : <gurobi.LinExpr: x0,17> >= 0.0
#    (7) : <gurobi.LinExpr: x0,18> >= 0.0
#    (7) : <gurobi.LinExpr: x0,19> >= 0.0
#    (7) : <gurobi.LinExpr: x0,20> >= 0.0
#    (7) : <gurobi.LinExpr: x0,21> >= 0.0
#    (7) : <gurobi.LinExpr: x0,22> >= 0.0
#    (7) : <gurobi.LinExpr: x0,23> >= 0.0
#    (7) : <gurobi.LinExpr: x0,24> >= 0.0
#    (7) : <gurobi.LinExpr: x0,25> >= 0.0
#    (7) : <gurobi.LinExpr: x0,26> >= 0.0
#    (7) : <gurobi.LinExpr: x0,27> >= 0.0
#    (7) : <gurobi.LinExpr: x0,28> >= 0.0
#    (7) : <gurobi.LinExpr: x0,29> >= 0.0
#    (7) : <gurobi.LinExpr: x0,30> >= 0.0
#    (7) : <gurobi.LinExpr: x0,31> >= 0.0
#    (7) : <gurobi.LinExpr: x0,32> >= 0.0
#    (7) : <gurobi.LinExpr: x0,33> >= 0.0
#    (7) : <gurobi.LinExpr: x0,34> >= 0.0
#    (7) : <gurobi.LinExpr: x0,35> >= 0.0
#    (7) : <gurobi.LinExpr: x0,36> >= 0.0
#    (7) : <gurobi.LinExpr: x0,37> >= 0.0
#    (7) : <gurobi.LinExpr: x0,38> >= 0.0
#    (7) : <gurobi.LinExpr: x0,39> >= 0.0
#    (7) : <gurobi.LinExpr: x1,0> >= 0.0
#    (7) : <gurobi.LinExpr: x1,1> >= 0.0
#    (7) : <gurobi.LinExpr: x1,2> >= 0.0
#    (7) : <gurobi.LinExpr: x1,3> >= 0.0
#    (7) : <gurobi.LinExpr: x1,4> >= 0.0
#    (7) : <gurobi.LinExpr: x1,5> >= 0.0
#    (7) : <gurobi.LinExpr: x1,6> >= 0.0
#    (7) : <gurobi.LinExpr: x1,7> >= 0.0
#    (7) : <gurobi.LinExpr: x1,8> >= 0.0
#    (7) : <gurobi.LinExpr: x1,9> >= 0.0
#    (7) : <gurobi.LinExpr: x1,10> >= 0.0
#    (7) : <gurobi.LinExpr: x1,11> >= 0.0
#    (7) : <gurobi.LinExpr: x1,12> >= 0.0
#    (7) : <gurobi.LinExpr: x1,13> >= 0.0
#    (7) : <gurobi.LinExpr: x1,14> >= 0.0
#    (7) : <gurobi.LinExpr: x1,15> >= 0.0
#    (7) : <gurobi.LinExpr: x1,16> >= 0.0
#    (7) : <gurobi.LinExpr: x1,17> >= 0.0
#    (7) : <gurobi.LinExpr: x1,18> >= 0.0
#    (7) : <gurobi.LinExpr: x1,19> >= 0.0
#    (7) : <gurobi.LinExpr: x1,20> >= 0.0
#    (7) : <gurobi.LinExpr: x1,21> >= 0.0
#    (7) : <gurobi.LinExpr: x1,22> >= 0.0
#    (7) : <gurobi.LinExpr: x1,23> >= 0.0
#    (7) : <gurobi.LinExpr: x1,24> >= 0.0
#    (7) : <gurobi.LinExpr: x1,25> >= 0.0
#    (7) : <gurobi.LinExpr: x1,26> >= 0.0
#    (7) : <gurobi.LinExpr: x1,27> >= 0.0
#    (7) : <gurobi.LinExpr: x1,28> >= 0.0
#    (7) : <gurobi.LinExpr: x1,29> >= 0.0
#    (7) : <gurobi.LinExpr: x1,30> >= 0.0
#    (7) : <gurobi.LinExpr: x1,31> >= 0.0
#    (7) : <gurobi.LinExpr: x1,32> >= 0.0
#    (7) : <gurobi.LinExpr: x1,33> >= 0.0
#    (7) : <gurobi.LinExpr: x1,34> >= 0.0
#    (7) : <gurobi.LinExpr: x1,35> >= 0.0
#    (7) : <gurobi.LinExpr: x1,36> >= 0.0
#    (7) : <gurobi.LinExpr: x1,37> >= 0.0
#    (7) : <gurobi.LinExpr: x1,38> >= 0.0
#    (7) : <gurobi.LinExpr: x1,39> >= 0.0
#    (7) : <gurobi.LinExpr: x2,0> >= 0.0
#    (7) : <gurobi.LinExpr: x2,1> >= 0.0
#    (7) : <gurobi.LinExpr: x2,2> >= 0.0
#    (7) : <gurobi.LinExpr: x2,3> >= 0.0
#    (7) : <gurobi.LinExpr: x2,4> >= 0.0
#    (7) : <gurobi.LinExpr: x2,5> >= 0.0
#    (7) : <gurobi.LinExpr: x2,6> >= 0.0
#    (7) : <gurobi.LinExpr: x2,7> >= 0.0
#    (7) : <gurobi.LinExpr: x2,8> >= 0.0
#    (7) : <gurobi.LinExpr: x2,9> >= 0.0
#    (7) : <gurobi.LinExpr: x2,10> >= 0.0
#    (7) : <gurobi.LinExpr: x2,11> >= 0.0
#    (7) : <gurobi.LinExpr: x2,12> >= 0.0
#    (7) : <gurobi.LinExpr: x2,13> >= 0.0
#    (7) : <gurobi.LinExpr: x2,14> >= 0.0
#    (7) : <gurobi.LinExpr: x2,15> >= 0.0
#    (7) : <gurobi.LinExpr: x2,16> >= 0.0
#    (7) : <gurobi.LinExpr: x2,17> >= 0.0
#    (7) : <gurobi.LinExpr: x2,18> >= 0.0
#    (7) : <gurobi.LinExpr: x2,19> >= 0.0
#    (7) : <gurobi.LinExpr: x2,20> >= 0.0
#    (7) : <gurobi.LinExpr: x2,21> >= 0.0
#    (7) : <gurobi.LinExpr: x2,22> >= 0.0
#    (7) : <gurobi.LinExpr: x2,23> >= 0.0
#    (7) : <gurobi.LinExpr: x2,24> >= 0.0
#    (7) : <gurobi.LinExpr: x2,25> >= 0.0
#    (7) : <gurobi.LinExpr: x2,26> >= 0.0
#    (7) : <gurobi.LinExpr: x2,27> >= 0.0
#    (7) : <gurobi.LinExpr: x2,28> >= 0.0
#    (7) : <gurobi.LinExpr: x2,29> >= 0.0
#    (7) : <gurobi.LinExpr: x2,30> >= 0.0
#    (7) : <gurobi.LinExpr: x2,31> >= 0.0
#    (7) : <gurobi.LinExpr: x2,32> >= 0.0
#    (7) : <gurobi.LinExpr: x2,33> >= 0.0
#    (7) : <gurobi.LinExpr: x2,34> >= 0.0
#    (7) : <gurobi.LinExpr: x2,35> >= 0.0
#    (7) : <gurobi.LinExpr: x2,36> >= 0.0
#    (7) : <gurobi.LinExpr: x2,37> >= 0.0
#    (7) : <gurobi.LinExpr: x2,38> >= 0.0
#    (7) : <gurobi.LinExpr: x2,39> >= 0.0
# Binaries
#    ['x0,0', 'x0,1', 'x0,2', 'x0,3', 'x0,4', 'x0,5', 'x0,6', 'x0,7', 'x0,8', 'x0,9', 'x0,10', 'x0,11', 'x0,12', 'x0,13', 'x0,14', 'x0,15', 'x0,16', 'x0,17', 'x0,18', 'x0,19', 'x0,20', 'x0,21', 'x0,22', 'x0,23', 'x0,24', 'x0,25', 'x0,26', 'x0,27', 'x0,28', 'x0,29', 'x0,30', 'x0,31', 'x0,32', 'x0,33', 'x0,34', 'x0,35', 'x0,36', 'x0,37', 'x0,38', 'x0,39', 'x1,0', 'x1,1', 'x1,2', 'x1,3', 'x1,4', 'x1,5', 'x1,6', 'x1,7', 'x1,8', 'x1,9', 'x1,10', 'x1,11', 'x1,12', 'x1,13', 'x1,14', 'x1,15', 'x1,16', 'x1,17', 'x1,18', 'x1,19', 'x1,20', 'x1,21', 'x1,22', 'x1,23', 'x1,24', 'x1,25', 'x1,26', 'x1,27', 'x1,28', 'x1,29', 'x1,30', 'x1,31', 'x1,32', 'x1,33', 'x1,34', 'x1,35', 'x1,36', 'x1,37', 'x1,38', 'x1,39', 'x2,0', 'x2,1', 'x2,2', 'x2,3', 'x2,4', 'x2,5', 'x2,6', 'x2,7', 'x2,8', 'x2,9', 'x2,10', 'x2,11', 'x2,12', 'x2,13', 'x2,14', 'x2,15', 'x2,16', 'x2,17', 'x2,18', 'x2,19', 'x2,20', 'x2,21', 'x2,22', 'x2,23', 'x2,24', 'x2,25', 'x2,26', 'x2,27', 'x2,28', 'x2,29', 'x2,30', 'x2,31', 'x2,32', 'x2,33', 'x2,34', 'x2,35', 'x2,36', 'x2,37', 'x2,38', 'x2,39']
# General Integers
#    ['c0,0', 'c0,1', 'c0,2', 'c0,3', 'c0,4', 'c0,5', 'c0,6', 'c0,7', 'c0,8', 'c0,9', 'c0,10', 'c0,11', 'c0,12', 'c0,13', 'c0,14', 'c0,15', 'c0,16', 'c0,17', 'c0,18', 'c0,19', 'c0,20', 'c0,21', 'c0,22', 'c0,23', 'c0,24', 'c0,25', 'c0,26', 'c0,27', 'c0,28', 'c0,29', 'c0,30', 'c0,31', 'c0,32', 'c0,33', 'c0,34', 'c0,35', 'c0,36', 'c0,37', 'c0,38', 'c0,39', 'c1,0', 'c1,1', 'c1,2', 'c1,3', 'c1,4', 'c1,5', 'c1,6', 'c1,7', 'c1,8', 'c1,9', 'c1,10', 'c1,11', 'c1,12', 'c1,13', 'c1,14', 'c1,15', 'c1,16', 'c1,17', 'c1,18', 'c1,19', 'c1,20', 'c1,21', 'c1,22', 'c1,23', 'c1,24', 'c1,25', 'c1,26', 'c1,27', 'c1,28', 'c1,29', 'c1,30', 'c1,31', 'c1,32', 'c1,33', 'c1,34', 'c1,35', 'c1,36', 'c1,37', 'c1,38', 'c1,39', 'c2,0', 'c2,1', 'c2,2', 'c2,3', 'c2,4', 'c2,5', 'c2,6', 'c2,7', 'c2,8', 'c2,9', 'c2,10', 'c2,11', 'c2,12', 'c2,13', 'c2,14', 'c2,15', 'c2,16', 'c2,17', 'c2,18', 'c2,19', 'c2,20', 'c2,21', 'c2,22', 'c2,23', 'c2,24', 'c2,25', 'c2,26', 'c2,27', 'c2,28', 'c2,29', 'c2,30', 'c2,31', 'c2,32', 'c2,33', 'c2,34', 'c2,35', 'c2,36', 'c2,37', 'c2,38', 'c2,39']

# %%
ans = {}
for var in model.getVars(): 
    if(var.varName[0] == 'x' and var.x > 0.01):
        print('{name} : {val}'.format(name=var.varName, val = var.x))
        key = var.varName.split(',')
        ans[key[1]] = key[0][1:]
#     if(var.varName[0] == 'c' and var.x > 0):
#         print('{name} : {val}'.format(name=var.varName, val = var.x))
list = [None]*len(ans)
for key in ans:
    list[int(key)] = int(ans[key])+1
# Out:
# x0,3 : 1.0
# x0,9 : 1.0
# x1,0 : 1.0
# x1,1 : 1.0
# x1,8 : 1.0
# x2,2 : 1.0
# x2,4 : 1.0
# x2,5 : 1.0
# x2,6 : 1.0
# x2,7 : 1.0

# %%
def totalS(V):
    total = 0
    for i in range(1,V+1):
        total+=i
    return total
def score(list,n,V,dis):
    scores = 0
    penalty = 0
    flag = False
    for j in range(1,n+1):
#        move.clear();
        curr_score = 0
        for i in range(len(list)):
            flag = False
            if(list[i] == j):
#                 // move.push_back(V);
                curr_score += V
            else:
#                 // max{0, i-V+1} ... i - 1
                index = 0
                if(i - V + 1 > index):
                    index = i - V + 1
                k = i - 1
                while(k >= index):
                    if(list[k] == j):
                        flag = True
#                         // move.push_back((V-(i-k)))
                        curr_score += V-(i-k)
                        break
                    k -= 1
#         // 補償t = list.size() 後沒加上的距離
#         i = len(list)-1
# #         print(i)
#         while( i >= len(list) - V):
#             if(list[i] == j):
#                 curr_score += totalS(V- (len(list) - i))
#                 break
#             i-=1
        scores += curr_score
        if(curr_score - dis[j-1] < 0):
            penalty += curr_score - dis[j-1]
        else:
            penalty += 1
        
    if(penalty == 3):
#         // 都有達到目標
        penalty = 10
    return scores, penalty

# %%
# list = [2,2,3,1,3]
dis = [5.0, 7.07, 9.21]
scores, penalty = score(list,len(p),V,dis)
print(list)
print(scores)
# print(penalty)
# Out:
# [2, 2, 3, 1, 3, 3, 3, 3, 2, 1]
# 47
